# %% [markdown]
# # 作業目標:¶
# 利用手寫辨識資料說明MLP 中, 神經網路層的多寡跟預測結果的差異

# %% [markdown]
# # 作業重點:
# [練習]請嘗試新增一層或兩層看看最後預測結果是否有差異
# model.add(Dense(units=256, input_dim=784, kernel_initializer='normal', activation='relu'))

# %% [markdown]
# # 資料預處理

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# from tensorflow.keras.utils import np_utils
import numpy as np
np.random.seed(10)

# %%
#載入手寫辨識的資料集
from keras.datasets import mnist
(x_train_image,y_train_label),\
(x_test_image,y_test_label)= mnist.load_data()
# Out:
# Using TensorFlow backend.

# %%
#指定測試集與訓練資料集
x_Train =x_train_image.reshape(60000, 784).astype('float32')
x_Test = x_test_image.reshape(10000, 784).astype('float32')

# %%
# normalize inputs from 0-255 to 0-1
x_Train_normalize = x_Train / 255
x_Test_normalize = x_Test / 255

# %%
#把LABEL轉成NUMERICAL Categorical 
y_Train_OneHot = tf.keras.utils.to_categorical(y_train_label)
y_Test_OneHot = tf.keras.utils.to_categorical(y_test_label)

# %% [markdown]
# # 建立模型

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
#建立模型

# %%
#宣告採用序列模型
model = Sequential()
#建構輸入層
model.add(Dense(units=256, 
                input_dim=784, 
                kernel_initializer='normal', 
                activation='relu'))

model.add(Dense(units=256, input_dim=784, kernel_initializer='normal', activation='relu'))

#建構輸出層
model.add(Dense(units=10, 
                kernel_initializer='normal', 
                activation='softmax'))

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 269,322
# Trainable params: 269,322
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 訓練模型

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

# %%
train_history =model.fit(x=x_Train_normalize,
                         y=y_Train_OneHot,validation_split=0.2, 
                         epochs=10, batch_size=32,verbose=1)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 4s 79us/sample - loss: 0.2354 - accuracy: 0.9291 - val_loss: 0.1172 - val_accuracy: 0.9654
# Epoch 2/10
# 48000/48000 [==============================] - 3s 70us/sample - loss: 0.0948 - accuracy: 0.9703 - val_loss: 0.1029 - val_accuracy: 0.9682
# Epoch 3/10
# 48000/48000 [==============================] - 3s 70us/sample - loss: 0.0625 - accuracy: 0.9812 - val_loss: 0.0942 - val_accuracy: 0.9718
# Epoch 4/10
# 48000/48000 [==============================] - 3s 71us/sample - loss: 0.0467 - accuracy: 0.9849 - val_loss: 0.1012 - val_accuracy: 0.9714
# Epoch 5/10
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.0364 - accuracy: 0.9885 - val_loss: 0.0941 - val_accuracy: 0.9769
# Epoch 6/10
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.0310 - accuracy: 0.9897 - val_loss: 0.0946 - val_accuracy: 0.9752
# Epoch 7/10
# 48000/48000 [==============================] - 3s 69us/sample - loss: 0.0232 - accuracy: 0.9926 - val_loss: 0.1027 - val_accuracy: 0.9773
# Epoch 8/10
# 48000/48000 [==============================] - 3s 70us/sample - loss: 0.0241 - accuracy: 0.9925 - val_loss: 0.0973 - val_accuracy: 0.9778
# Epoch 9/10
# 48000/48000 [==============================] - 3s 71us/sample - loss: 0.0191 - accuracy: 0.9936 - val_loss: 0.1126 - val_accuracy: 0.9738
# Epoch 10/10
# 48000/48000 [==============================] - 3s 71us/sample - loss: 0.0169 - accuracy: 0.9944 - val_loss: 0.1119 - val_accuracy: 0.9772

# %% [markdown]
# # 以圖形顯示訓練過程

# %%
import matplotlib.pyplot as plt
def show_train_history(train_history,train,validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

# %%
show_train_history(train_history,'acc','val_acc')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-0f5605080d27> in <module>
# ----> 1 show_train_history(train_history,'acc','val_acc')
#
# <ipython-input-12-48448a1ec165> in show_train_history(train_history, train, validation)
#       1 import matplotlib.pyplot as plt
#       2 def show_train_history(train_history,train,validation):
# ----> 3     plt.plot(train_history.history[train])
#       4     plt.plot(train_history.history[validation])
#       5     plt.title('Train History')
#
# KeyError: 'acc'

# %%
show_train_history(train_history,'loss','val_loss')

# %% [markdown]
# # 評估模型準確率

# %%
scores = model.evaluate(x_Test_normalize, y_Test_OneHot)
print()
print('accuracy=',scores[1])
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# accuracy= 0.978
