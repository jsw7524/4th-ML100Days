# %% [markdown]
# #
#
# # 作業目標:
#
#     1. 藉由固定的 dataset, 來驗證不同loss function
#     2. Dataset 的特性跟我們選用的loss function 對accrancy 的影響
#
#
# # 作業重點:
#     請分別選用 "MSE", "binary _crossentropy"
#     查看Train/test accurancy and loss rate

# %% [markdown]
# # 導入必要的函數

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.datasets import cifar10
import numpy as np
np.random.seed(10)

# %% [markdown]
# # 資料準備

# %%
#取得Keras Dataset
(x_img_train,y_label_train),(x_img_test,y_label_test)=cifar10.load_data()

# %%
#確認 CIFAR10 Dataset 資料維度
print("train data:",'images:',x_img_train.shape,
      " labels:",y_label_train.shape) 
print("test  data:",'images:',x_img_test.shape ,
      " labels:",y_label_test.shape)
# Out:
# train data: images: (50000, 32, 32, 3)  labels: (50000, 1)
# test  data: images: (10000, 32, 32, 3)  labels: (10000, 1)

# %%
#資料正規化
x_img_train_normalize = x_img_train.astype('float32') / 255.0
x_img_test_normalize = x_img_test.astype('float32') / 255.0

# %%
#針對Label 做 ONE HOT ENCODE
from keras.utils import np_utils
y_label_train_OneHot = np_utils.to_categorical(y_label_train)
y_label_test_OneHot = np_utils.to_categorical(y_label_test)
y_label_test_OneHot.shape
# Out:
# Using TensorFlow backend.
# (10000, 10)

# %% [markdown]
# # 建立模型

# %%
model = Sequential()

# %%
#卷積層1

# %%
model.add(Conv2D(filters=32,kernel_size=(3,3),
                 input_shape=(32, 32,3), 
                 activation='relu', 
                 padding='same'))

# %%
model.add(Dropout(rate=0.25))

# %%
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
#卷積層2與池化層2

# %%
model.add(Conv2D(filters=64, kernel_size=(3, 3), 
                 activation='relu', padding='same'))

# %%
model.add(Dropout(0.25))

# %%
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
#建立神經網路(平坦層、隱藏層、輸出層)

# %%
model.add(Flatten())
model.add(Dropout(rate=0.25))

# %%
model.add(Dense(1024, activation='relu'))
model.add(Dropout(rate=0.25))

# %%
model.add(Dense(10, activation='softmax'))

# %%
#檢查model 的STACK
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              4195328
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 4,224,970
# Trainable params: 4,224,970
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 載入之前訓練的模型

# %%
try:
    model.load_weights("SaveModel/cifarCnnModel.h5")
    print("載入模型成功!繼續訓練模型")
except :    
    print("載入模型失敗!開始訓練一個新模型")
# Out:
# 載入模型失敗!開始訓練一個新模型

# %% [markdown]
# # 訓練模型

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#定義一個繪圖函數
def show_train_history(train_acc,test_acc):
    plt.plot(train_history.history[train_acc])
    plt.plot(train_history.history[test_acc])
    plt.title('Train History')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['train_acc', 'val_acc'], loc='upper left')
    plt.show()

'''
作業:
請分別選用 "MSE", "binary _crossentropy"
查看Train/test accurancy and loss rate
'''
# Out:
# '\n作業:\n請分別選用 "MSE", "binary _crossentropy"\n查看Train/test accurancy and loss rate\n'

# %%
model.compile(loss="MSE", optimizer='sgd', metrics=['accuracy'])
train_history=model.fit(x_img_train_normalize, y_label_train_OneHot,
                        validation_split=0.25,
                        epochs=12, batch_size=128, verbose=1)    
show_train_history('acc','val_acc')
# Out:
# Train on 37500 samples, validate on 12500 samples
# Epoch 1/12
# 37500/37500 [==============================] - 51s 1ms/sample - loss: 0.0776 - accuracy: 0.3586 - val_loss: 0.0796 - val_accuracy: 0.3803
# Epoch 2/12
# 37500/37500 [==============================] - 50s 1ms/sample - loss: 0.0773 - accuracy: 0.3611 - val_loss: 0.0793 - val_accuracy: 0.3806
# Epoch 3/12
# 37500/37500 [==============================] - 50s 1ms/sample - loss: 0.0772 - accuracy: 0.3633 - val_loss: 0.0791 - val_accuracy: 0.3833
# Epoch 4/12
# 37500/37500 [==============================] - 50s 1ms/sample - loss: 0.0771 - accuracy: 0.3617 - val_loss: 0.0790 - val_accuracy: 0.3838
# Epoch 5/12
# 37500/37500 [==============================] - 50s 1ms/sample - loss: 0.0770 - accuracy: 0.3650 - val_loss: 0.0788 - val_accuracy: 0.3838
# Epoch 6/12
# 37500/37500 [==============================] - 50s 1ms/sample - loss: 0.0767 - accuracy: 0.3692 - val_loss: 0.0787 - val_accuracy: 0.3850
# Epoch 7/12
# 37500/37500 [==============================] - 50s 1ms/sample - loss: 0.0766 - accuracy: 0.3687 - val_loss: 0.0786 - val_accuracy: 0.3867
# Epoch 8/12
# 37500/37500 [==============================] - 50s 1ms/sample - loss: 0.0765 - accuracy: 0.3705 - val_loss: 0.0784 - val_accuracy: 0.3889
# Epoch 9/12
# 37500/37500 [==============================] - 51s 1ms/sample - loss: 0.0764 - accuracy: 0.3719 - val_loss: 0.0783 - val_accuracy: 0.3886
# Epoch 10/12
# 37500/37500 [==============================] - 51s 1ms/sample - loss: 0.0764 - accuracy: 0.3689 - val_loss: 0.0782 - val_accuracy: 0.3897
# Epoch 11/12
# 37500/37500 [==============================] - 51s 1ms/sample - loss: 0.0762 - accuracy: 0.3740 - val_loss: 0.0781 - val_accuracy: 0.3913
# Epoch 12/12
# 37500/37500 [==============================] - 51s 1ms/sample - loss: 0.0761 - accuracy: 0.3783 - val_loss: 0.0780 - val_accuracy: 0.3921
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-b3830f357497> in <module>
#       3                         validation_split=0.25,
#       4                         epochs=12, batch_size=128, verbose=1)
# ----> 5 show_train_history('acc','val_acc')
#
# <ipython-input-21-b9db2bf73f1a> in show_train_history(train_acc, test_acc)
#       4 #定義一個繪圖函數
#       5 def show_train_history(train_acc,test_acc):
# ----> 6     plt.plot(train_history.history[train_acc])
#       7     plt.plot(train_history.history[test_acc])
#       8     plt.title('Train History')
#
# KeyError: 'acc'

# %%
show_train_history('loss','val_loss')
score, acc = model.evaluate(x_img_test_normalize, y_label_test_OneHot, batch_size=128)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test score: 0.07762668199539184
# Test accuracy: 0.4047

# %%
model.compile(loss="binary_crossentropy", optimizer='sgd', metrics=['accuracy'])
train_history=model.fit(x_img_train_normalize, y_label_train_OneHot,
                        validation_split=0.25,
                        epochs=12, batch_size=128, verbose=1)
# Out:
# Train on 37500 samples, validate on 12500 samples
# Epoch 1/12
# 37500/37500 [==============================] - 52s 1ms/sample - loss: 0.2626 - accuracy: 0.9038 - val_loss: 0.2700 - val_accuracy: 0.9006
# Epoch 2/12
# 37500/37500 [==============================] - 51s 1ms/sample - loss: 0.2604 - accuracy: 0.9042 - val_loss: 0.2686 - val_accuracy: 0.9007
# Epoch 3/12
# 37500/37500 [==============================] - 50s 1ms/sample - loss: 0.2591 - accuracy: 0.9042 - val_loss: 0.2672 - val_accuracy: 0.9007
# Epoch 4/12
# 37500/37500 [==============================] - 50s 1ms/sample - loss: 0.2575 - accuracy: 0.9048 - val_loss: 0.2657 - val_accuracy: 0.9008
# Epoch 5/12
# 37500/37500 [==============================] - 51s 1ms/sample - loss: 0.2560 - accuracy: 0.9050 - val_loss: 0.2644 - val_accuracy: 0.9010
# Epoch 6/12
# 37500/37500 [==============================] - 52s 1ms/sample - loss: 0.2539 - accuracy: 0.9055 - val_loss: 0.2626 - val_accuracy: 0.9011
# Epoch 7/12
# 37500/37500 [==============================] - 51s 1ms/sample - loss: 0.2533 - accuracy: 0.9055 - val_loss: 0.2614 - val_accuracy: 0.9012
# Epoch 8/12
# 37500/37500 [==============================] - 52s 1ms/sample - loss: 0.2519 - accuracy: 0.9056 - val_loss: 0.2603 - val_accuracy: 0.9015
# Epoch 9/12
# 37500/37500 [==============================] - 51s 1ms/sample - loss: 0.2503 - accuracy: 0.9060 - val_loss: 0.2589 - val_accuracy: 0.9020
# Epoch 10/12
# 37500/37500 [==============================] - 52s 1ms/sample - loss: 0.2491 - accuracy: 0.9064 - val_loss: 0.2580 - val_accuracy: 0.9020
# Epoch 11/12
# 37500/37500 [==============================] - 51s 1ms/sample - loss: 0.2482 - accuracy: 0.9065 - val_loss: 0.2567 - val_accuracy: 0.9018
# Epoch 12/12
# 37500/37500 [==============================] - 53s 1ms/sample - loss: 0.2468 - accuracy: 0.9069 - val_loss: 0.2555 - val_accuracy: 0.9022
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-50273ec1f5f8> in <module>
#       3                         validation_split=0.25,
#       4                         epochs=12, batch_size=128, verbose=1)
# ----> 5 show_train_history('acc','val_acc')
#
# <ipython-input-21-b9db2bf73f1a> in show_train_history(train_acc, test_acc)
#       4 #定義一個繪圖函數
#       5 def show_train_history(train_acc,test_acc):
# ----> 6     plt.plot(train_history.history[train_acc])
#       7     plt.plot(train_history.history[test_acc])
#       8     plt.title('Train History')
#
# KeyError: 'acc'

# %%
show_train_history('loss','val_loss')
score, acc = model.evaluate(x_img_test_normalize, y_label_test_OneHot, batch_size=128)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test score: 0.25382950191497805
# Test accuracy: 0.9025201
